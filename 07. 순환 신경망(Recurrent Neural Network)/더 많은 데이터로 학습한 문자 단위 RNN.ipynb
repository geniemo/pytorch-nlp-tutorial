# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim

# %%
sentence = (
    "if you want to build a ship, don't drum up people together to "
    "collect wood and don't assign them tasks and work, but rather "
    "teach them to long for the endless immensity of the sea."
)

# %%
char_set = list(set(sentence))
char_dic = {c: i for i, c in enumerate(char_set)}
char_dic
# Out:
# {'u': 0,
#  "'": 1,
#  'i': 2,
#  'f': 3,
#  'a': 4,
#  ' ': 5,
#  'c': 6,
#  'e': 7,
#  'g': 8,
#  '.': 9,
#  'w': 10,
#  'p': 11,
#  ',': 12,
#  'k': 13,
#  'y': 14,
#  'b': 15,
#  'd': 16,
#  't': 17,
#  's': 18,
#  'm': 19,
#  'h': 20,
#  'l': 21,
#  'n': 22,
#  'r': 23,
#  'o': 24}

# %%
dic_size = len(char_dic)
dic_size
# Out:
# 25

# %%
hidden_size = dic_size
sequence_length = 10
lr = 0.1

# %%
x_data = []
y_data = []

for i in range(0, len(sentence) - sequence_length):
    x_str = sentence[i : i + sequence_length]
    y_str = sentence[i + 1 : i + 1 + sequence_length]
    print(i, x_str, "->", y_str)

    x_data.append([char_dic[c] for c in x_str])
    y_data.append([char_dic[c] for c in y_str])

x_data[0], y_data[0]
# Out:
# 0 if you wan -> f you want
# 1 f you want ->  you want
# 2  you want  -> you want t
# 3 you want t -> ou want to
# 4 ou want to -> u want to
# 5 u want to  ->  want to b
# 6  want to b -> want to bu
# 7 want to bu -> ant to bui
# 8 ant to bui -> nt to buil
# 9 nt to buil -> t to build
# 10 t to build ->  to build
# 11  to build  -> to build a
# 12 to build a -> o build a
# 13 o build a  ->  build a s
# 14  build a s -> build a sh
# 15 build a sh -> uild a shi
# 16 uild a shi -> ild a ship
# 17 ild a ship -> ld a ship,
# 18 ld a ship, -> d a ship,
# 19 d a ship,  ->  a ship, d
# 20  a ship, d -> a ship, do
# 21 a ship, do ->  ship, don
# 22  ship, don -> ship, don'
# 23 ship, don' -> hip, don't
# 24 hip, don't -> ip, don't
# 25 ip, don't  -> p, don't d
# 26 p, don't d -> , don't dr
# 27 , don't dr ->  don't dru
# 28  don't dru -> don't drum
# 29 don't drum -> on't drum
# 30 on't drum  -> n't drum u
# 31 n't drum u -> 't drum up
# 32 't drum up -> t drum up
# 33 t drum up  ->  drum up p
# 34  drum up p -> drum up pe
# 35 drum up pe -> rum up peo
# 36 rum up peo -> um up peop
# 37 um up peop -> m up peopl
# 38 m up peopl ->  up people
# 39  up people -> up people
# 40 up people  -> p people t
# 41 p people t ->  people to
# 42  people to -> people tog
# 43 people tog -> eople toge
# 44 eople toge -> ople toget
# 45 ople toget -> ple togeth
# 46 ple togeth -> le togethe
# 47 le togethe -> e together
# 48 e together ->  together
# 49  together  -> together t
# 50 together t -> ogether to
# 51 ogether to -> gether to
# 52 gether to  -> ether to c
# 53 ether to c -> ther to co
# 54 ther to co -> her to col
# 55 her to col -> er to coll
# 56 er to coll -> r to colle
# 57 r to colle ->  to collec
# 58  to collec -> to collect
# 59 to collect -> o collect
# 60 o collect  ->  collect w
# 61  collect w -> collect wo
# 62 collect wo -> ollect woo
# 63 ollect woo -> llect wood
# 64 llect wood -> lect wood
# 65 lect wood  -> ect wood a
# 66 ect wood a -> ct wood an
# 67 ct wood an -> t wood and
# 68 t wood and ->  wood and
# 69  wood and  -> wood and d
# 70 wood and d -> ood and do
# 71 ood and do -> od and don
# 72 od and don -> d and don'
# 73 d and don' ->  and don't
# 74  and don't -> and don't
# 75 and don't  -> nd don't a
# 76 nd don't a -> d don't as
# 77 d don't as ->  don't ass
# 78  don't ass -> don't assi
# 79 don't assi -> on't assig
# 80 on't assig -> n't assign
# 81 n't assign -> 't assign
# 82 't assign  -> t assign t
# 83 t assign t ->  assign th
# 84  assign th -> assign the
# 85 assign the -> ssign them
# 86 ssign them -> sign them
# 87 sign them  -> ign them t
# 88 ign them t -> gn them ta
# 89 gn them ta -> n them tas
# 90 n them tas ->  them task
# 91  them task -> them tasks
# 92 them tasks -> hem tasks
# 93 hem tasks  -> em tasks a
# 94 em tasks a -> m tasks an
# 95 m tasks an ->  tasks and
# 96  tasks and -> tasks and
# 97 tasks and  -> asks and w
# 98 asks and w -> sks and wo
# 99 sks and wo -> ks and wor
# 100 ks and wor -> s and work
# 101 s and work ->  and work,
# 102  and work, -> and work,
# 103 and work,  -> nd work, b
# 104 nd work, b -> d work, bu
# 105 d work, bu ->  work, but
# 106  work, but -> work, but
# 107 work, but  -> ork, but r
# 108 ork, but r -> rk, but ra
# 109 rk, but ra -> k, but rat
# 110 k, but rat -> , but rath
# 111 , but rath ->  but rathe
# 112  but rathe -> but rather
# 113 but rather -> ut rather
# 114 ut rather  -> t rather t
# 115 t rather t ->  rather te
# 116  rather te -> rather tea
# 117 rather tea -> ather teac
# 118 ather teac -> ther teach
# 119 ther teach -> her teach
# 120 her teach  -> er teach t
# 121 er teach t -> r teach th
# 122 r teach th ->  teach the
# 123  teach the -> teach them
# 124 teach them -> each them
# 125 each them  -> ach them t
# 126 ach them t -> ch them to
# 127 ch them to -> h them to
# 128 h them to  ->  them to l
# 129  them to l -> them to lo
# 130 them to lo -> hem to lon
# 131 hem to lon -> em to long
# 132 em to long -> m to long
# 133 m to long  ->  to long f
# 134  to long f -> to long fo
# 135 to long fo -> o long for
# 136 o long for ->  long for
# 137  long for  -> long for t
# 138 long for t -> ong for th
# 139 ong for th -> ng for the
# 140 ng for the -> g for the
# 141 g for the  ->  for the e
# 142  for the e -> for the en
# 143 for the en -> or the end
# 144 or the end -> r the endl
# 145 r the endl ->  the endle
# 146  the endle -> the endles
# 147 the endles -> he endless
# 148 he endless -> e endless
# 149 e endless  ->  endless i
# 150  endless i -> endless im
# 151 endless im -> ndless imm
# 152 ndless imm -> dless imme
# 153 dless imme -> less immen
# 154 less immen -> ess immens
# 155 ess immens -> ss immensi
# 156 ss immensi -> s immensit
# 157 s immensit ->  immensity
# 158  immensity -> immensity
# 159 immensity  -> mmensity o
# 160 mmensity o -> mensity of
# 161 mensity of -> ensity of
# 162 ensity of  -> nsity of t
# 163 nsity of t -> sity of th
# 164 sity of th -> ity of the
# 165 ity of the -> ty of the
# 166 ty of the  -> y of the s
# 167 y of the s ->  of the se
# 168  of the se -> of the sea
# 169 of the sea -> f the sea.
# ([2, 3, 5, 14, 24, 0, 5, 10, 4, 22], [3, 5, 14, 24, 0, 5, 10, 4, 22, 17])

# %%
x_one_hot = [np.eye(dic_size)[x] for x in x_data]
X = torch.FloatTensor(x_one_hot)
y = torch.LongTensor(y_data)
X.shape, y.shape
# Out:
# C:\Users\jiweo\AppData\Local\Temp\ipykernel_34080\3269659559.py:2: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at C:\cb\pytorch_1000000000000\work\torch\csrc\utils\tensor_new.cpp:281.)
#   X = torch.FloatTensor(x_one_hot)
# (torch.Size([170, 10, 25]), torch.Size([170, 10]))

# %%
class Net(nn.Module):
    def __init__(self, input_dim, hidden_dim, layers):
        super().__init__()
        self.rnn = nn.RNN(input_dim, hidden_dim, num_layers=layers, batch_first=True)
        self.fc = nn.Linear(hidden_dim, hidden_dim, bias=True)

    def forward(self, x):
        x, _status = self.rnn(x)
        x = self.fc(x)
        return x

# %%
net = Net(dic_size, hidden_size, 2)

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(net.parameters(), lr=lr)

# %%
for i in range(100):
    optimizer.zero_grad()
    outputs = net(X)
    loss = criterion(outputs.view(-1, dic_size), y.view(-1))
    loss.backward()
    optimizer.step()

    results = outputs.argmax(dim=2)
    predict_str = ""
    for j, result in enumerate(results):
        if j == 0:
            predict_str += "".join([char_set[t] for t in result])
        else:
            predict_str += char_set[result[-1]]

    print(predict_str, end="\n\n")
# Out:
# bu''''''''t'''''o''o'''''bu''u''a'''''c'uo'u''u'''''''''''''''''''''''''''''''''''a''''cb''''''''''''c''''''''a''uo'''''''''''''''t'''''''''''''''o'''''''''ccbt''''c''''''''''''''
#
# ttttttttttttttttttttttttttttttttttttttttttttttttttttttttttttttttttttttttttttttttttttttttttttttttttttttttttttttttttttttttttttttttttttttttttttttttttttttttttttttttttttttttttttttttttt
#
# o,t o,t o,,l,l,lg,,ll,,,g,,,ll,lgl,,og,,l,,ol,,lll,,,o,,,gl,,lo,,lll,,lg,,,l,,l,,,lg,,lg,,ll,,,gl,,,,,,g,lll,ocllll,ll,,,lg,,lgl,,ol,,l,,lo,,lo,,ll,,.gl,,ll,,l,og,,lgl,lg,,ol,b,,,
#
# oooooooooo ooo o oo o o o o o o o oooooooo o ooo ooo o oo ooooooooooooooooo o o o o o ooooo o o ooo o ooo o o o o o o oooo ooooo oooooooooo o ooo o ooooo o o o o o  o o ooooooooo
#
#   d s d d d d  d d      d d d d h d d d     dd     d            d d           d   d d d d     d d d   d     d d d d d d d      d d d   d    d     d   n d d     d d   d    d d  hd
#
#    u ute ttttt t t  tt tt t ttttttt tut    ttt  t  t      tt    t ttt t       t t tnt tut    ttnt t t t  t tt tnt ttt t ttt  t t t ttt t tt t ttt t t  tt  t t tt t  t ttttt tt tt
#
# t  unctettttetetetett tetetetetti teteteeetentetneet t te tt et tetetet tee titetetetetet eetet ietet ttt ttnenetet tetettteettt t t tet tt tetet tetee tet t teteneciutetttei ttt
#
# th ptpth ttth ptlt ltltltlt tltlt tltltll l  tlt lh lthtl t  lt t  l lh  leltltltltltltlt llt tepltp lttt t  lt tlt tltltltlh lt tttl pt tt t tl lt  peltlt tltl    ptltl lt tltttl
#
#  h p  t  t t  lt t   hthth  t     th l eh      t  h lth    h lt te t t   hth lt  ht th  th lt   th h  t   t  lt t   t      lh  t t    tt  t   th  th ceht t  ht    ttth    t     hh
#
#    t  t        t            t                  t     t    t   t te        e   t            t    e         e   e t              t          t       e   e   t             t  e   e
#
#  o  d to   to  t  d d d d   d   t   d  o   o   d eo  t    to  o to t eo   d d d   d e d d       do    d d do    d d t      eo  t t        d   to  d   d d d   do     do o  do  d d
#
# to  o tond to  t td d d dnd t r t t d  oo  o   o to  t  o to  o to t eo  od d t r t t d do  o t to tondnd to  o tod to  o  to  o to t to  o t tod t e tod d t dnd t  dndoo to  t dn
#
# to oe tond toe o to t t toa tor t toao ao  o   o tor t to tor o to t eoo odnd t r t tnr dorooot to tonont to  o tot torhor tor o toet to  o t tod t en nd t t toa o   oaoo to m ntn
#
# totoe tood toe o  u tothtoa tor t totoito  o   o thr t to toe o to t too  tnt t r t tot aoroo t to tonunt toe t tot torh r tor t thetetor o t toe t ememe t t totoo ktotoo to  e u
#
# totoectoog toe t iu ththtoo tor t toa  to  os  o tor theo toeco  e t toe  thd tor t tot turuoem to thiiot toe t toa tor eo tor t them to  o t toecthe enect t toa t ktoaoo the eha
#
# thtosctong tor t iu ththsnh tor t toaiiao bhn  tstog thia torlh te t toe  angltor t tniiaiauoem to kiiina tor t toaiiagher tos h them to lh t torltoemehdlt  iiaaeo kioaoh themehi
#
# poaosktong torltilaet dhips tor t tnai ah bon  a torlthen to lh te t to   ang torlt tnhiaa eoem to ksiind torl, toaiinnhem torlh them to lh t torltoe tnd d  iinien kinaao theme g
#
# loao ktond torloi d t dh p, ter't tnrp th bo tld torlthem torlo te t toel dnd deret tnhian eoem to ksndnd tor , toa tnnhem torlh them to lo t torltoe t d d siin em linaao theme dn
#
# loao ktond to los d t dh nd ter't dnrp do bo t o tor them to lo te t toet d d ter't dnh an eoem to ksndnd tor , toa dnrhem tor h ther to lo t tor dheme d d t in ems inaen thereksn
#
# l dorktond to lti d a dhin, tor't dnrp do tont o tor ther to lo le t toet dnd tor't dns in bhem to ks dnd tor , tod dnnher tor hether torlo t tor toeme d d tiinsems ihson themeksn
#
# l dor tond to lti d a dhsns tor't tnap to ton le tor ther to lo le t toet dnd tor't tnsiin them to ks ind tor , tod dnmher tor hether to lo t tor toeme d dnt insems th o ltheme sn
#
# l don tont th bti d a dhsns tor't dnam to ton le ton ther to lo lect to t dnd tor't dnsisn them to ks ind tor , tod dnshem tor h them to lo t ton toeme d dnsiinsems th o  themend
#
# l aoa tont th bti d a dhdn, ton't anam ao pontle toncther to lo lect tong und tor't ansi n them to ks and donc, tod anmhem toach them to long won toemendcdns insems th o  themena
#
# l aoa tont th luild a dhin, don't anam ao pontle to cther to co gect tong und dor't ansi n them to ks and donc, tod anmher tonchethem to long won themendcd s inmers thao  themena
#
# l uau tont to cuild a dhin, don't anam uo tentle to cther to lonlect wong und don't ansi n them to ks und donc, tut aomher tonchethem to cong ton toemendcdns inmersityuo  themena
#
# l uou tont wo luild u thim, don't dnam uo tenlle to 'ther to lonlect wong und don't dnsi n them to ks und donk, tut anmher torchethem to long won toemendldns immersity oe themena
#
# l uou tont wo ltild usthip, don't doam uh penlle to 'ther to lollect wonl und don't dnsisn them to ks and donk, tut apmhem to chethem to long fon toemsndld s immersity ae themena
#
# l aaa tont wo luild a dhip, don't doam ah penple toglther to lollect wonl and don't dnsisn them tosks and donk, tat aamhem toach ther to long fon themsndld s immersity af themsna
#
# l aaa tont to luild a thip, don't doam ao penple toglther to lollect wonl asd don't dssisn them tosks and donk, tat aamhem toach ther to long fon themendle s immersity oe ahemeha
#
# lhaad wont to cuild a thip, ton't aoam uo penple together to bollect wofg asd don't assign them tosks and tork, tpt aamher toach them to long fon themsnd e s immensity oe ahemsha
#
# lhuad wont to cuild a thip, ton't aoam uo penple together to collect wofg and don't ansign teem tosks and tork, tpt ramher torch them to cong fon themendle s immensity oe themeha
#
# lhupd wont to cuild a thip, ton't anam uo penple together th collect wond und don't ansign them tosks and dork, tpt ramher thach them to cong fon themendle s immensity of themeka
#
# l uad wont to cuild a thip, don't aoum uo penple together to collect wond and don't ansign teem tosks and dork, tut ramher toach them to cong fon the endle s immensity of toe sha
#
# l ,ad wont to cuild a thip, don't aoum up penple together to collect wond and don't ansign them tosks and dork, tut ramher toach them to long fon the endle s immensity of the sha
#
# b ,ad want wo cuild a thip, don't doum up penple together to collect wofd and don't dnsign them tosks and dork, tut ramher tosch them to long fon toe endle s immensity of the eka
#
# b aad want wo cuild a ship, don't doum ap people together to lollect wofd and don't dnsign them tosks and dork, tut ramher toach them to long fon toe endle s immensity of the ska
#
# b apu want wo build a ship, don't drum apspeople together to bollect wood and don't dnsign them tosks and dork, but rather toach them to long for toe endless immensity of the ssa
#
# b aou want to build a ship, don't arum up people together to bollect wood and don't ansign them tosks and dork, but rather toach them to long for toe endless immensity of the ska
#
# b aou want to build a ship, don't drum up people together to bollect word and don't dssign them thsks and dork, but rather toach them to bong for the sndless immensity of the skan
#
# l aou want to luild a ship, dor't doum up people together to lollect wood and don't dnsign them tosks and dork, but rather toach them to long for the endless immensity of the eka
#
# l aou want to build a ship, don't doum up people together to bollect wood and don't dnsign them tosks and dork, but rather toach them to bong for the endless immensity of the ska
#
# l aou want to build a ship, don't drum up people together to bollect wood and don't dnsign them tosks and tork, but rather toach them to bong for the sndless immensity of the sha
#
# t you want to cuild a ship, don't drum up people together to bollect wood and don't assign them tosks and dork, but rather toach them to long for the endless immensity of the eta
#
# t you want to cuild a ship, don't drum up people together to collect wood and don't dnsign them tosks and work, but rather toach them to long for the endless immensity of the sta
#
# t you want to cuild a ship, don't drum up people together to collect wood and don't dnsign them tosks and dor , but rather toach them to long for the endless immensity of the shan
#
# l you want to cuild a ship, don't drum up people together to collect wood and don't dnsign the  tosks and dork, but rather toach them to long for the endless immensity of the sta
#
# l you want to cuild a ship, don't drum up people together te collect wood and don't dnsign them tasks and dork, but rather teach them to long for the endless immensity of the sta
#
# p you want to build a ship, don't drum up people together to bollect wood and don't ansign them tasks and dork, but rather toach them to long for the endless immensity of the stap
#
# p you want to build a ship, don't arum up people together to bollect wood and don't assign them tasks and dork, but rather toach them to long for the endless immensity of the stan
#
# p you want to build a ship, don't drum up people together to bollect wood and don't assign them tasks and dork, but rather toach them to long for the endless immensity of the sta
#
# p you want to build a ship, don't drum up people together to bollect wood and don't dssign them tasks and dork, but rather toach them to long for the endless immensity of the sla
#
# p you want to build a ship, don't drum up people together to bollect wood and don't dssign them tasks and dork, but rather toach them to long for the endless immensity of the sta
#
# p you want to build a ship, don't drum up people together to collect wood and don't dssign them tasks and work, but rather toach them to long for the endless immensity of the stap
#
# p you want to cuild a ship, don't drum up people together to collect wood and don't dssign them tasks and work, but rather teach them ta long for the endless immensity of the sea
#
# p you want to cuild a ship, don't drum up people together to collect wood and don't assign them tasks and work, but rather teach them to long for the endless immensity of the sea
#
# p you want to cuild a ship, don't drum up people together to collect wood and don't assign them tasks and work, but rather teach them to long for the endless immensity of the sea
#
# p you want to cuild a ship, don't drum up people together to collect wood and don't dssign them tasks and work, but rather teach them to long for the endless immensity of the sea
#
# p you want to cuild a ship, don't drum up people together to collect wood and don't dssign them tasks and work, but rather teach them to long for the endless immensity of the sea
#
# p you want to cuild a ship, don't drum up people together to collect wood and don't assign them tasks and work, but rather teach them to long for the endless immensity of the sea
#
# p you want to cuild a ship, don't drum up people together to collect wood and don't dssign them tasks and work, but rather teach them ta long for the endless immensity of the sea
#
# p you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and work, but rather teach them to long for the endless immensity of the sea
#
# p you want to build a ship, don't drum up people together to bollect wood and don't assign them tasks and work, but rather teach them to long for the endless immensity of the sea
#
# p you want to build a ship, don't drum up people together to bollect wood and don't assign them tasks and work, but rather teach them to long for the endless immensity of the sea
#
# p you want to build a ship, don't drum up people together to bollect wood and don't assign them tasks and work, but rather teach them to long for the endless immensity of the seao
#
# p you want to build a ship, don't drum up people together to bollect wood and don't assign them tasks and work, but rather teach them to long for the endless immensity of the sea
#
# p you want to build a ship, don't drum up people together to bollect wood and don't assign them tasks and work, but rather teach them to long for the endless immensity of the sea
#
# p you want to build a ship, don't drum up people together to bollect wood and don't assign them tasks and work, but rather teach them to long for the endless immensity of the sea
#
# p you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and work, but rather teach them to long for the endless immensity of the seao
#
# m you want to build a ship, don't drum up people together to bollect wood and don't assign them tasks and work, but rather teach them to long for the endless immensity of the sea
#
# p you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and work, but rather teach them to long for the endless immensity of the sea.
#
# p you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and work, but rather teach them to long for the endless immensity of the sea.
#
# p you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and work, but rather teach them to long for the endless immensity of the sea.
#
# p you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and work, but rather teach them to long for the endless immensity of the sea.
#
# p you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and work, but rather teach them to long for the endless immensity of the sea.
#
# p you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and work, but rather teach them to long for the endless immensity of the sea.
#
# p you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and work, but rather teach them to long for the endless immensity of the sea.
#
# p you want to build a ship, don't drum up people together to collect wood and don't dssign them tasks and work, but rather teach them to long for the endless immensity of the sea.
#
# p you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and work, but rather teach them to long for the endless immensity of the sea.
#
# f you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and work, but rather teach them to long for the endless immensity of the sea.
#
# g you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and work, but rather teach them to long for the endless immensity of the sea.
#
# t you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and work, but rather teach them to long for the endless immensity of the sea.
#
# t you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and work, but rather teach them to long for the endless immensity of the sea.
#
# f you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and work, but rather teach them to long for the endless immensity of the sea.
#
# f you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and work, but rather teach them to long for the endless immensity of the sea.
#
# f you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and work, but rather teach them to long for the endless immensity of the sea.
#
# f you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and work, but rather teach them to long for the endless immensity of the sea.
#
# f you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and work, but rather teach them to long for the endless immensity of the sea.
#
# f you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and work, but rather teach them to long for the endless immensity of the sea.
#
# g you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and work, but rather teach them to long for the endless immensity of the sea.
#
# g you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and work, but rather teach them to long for the endless immensity of the sea.
#
# p you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and work, but rather teach them to long for the endless immensity of the sea.
#
# p you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and work, but rather teach them to long for the endless immensity of the sea.
#
# g you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and work, but rather teach them to long for the endless immensity of the sea.
#
# p you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and work, but rather teach them to long for the endless immensity of the sea.
#
# m you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and work, but rather teach them to long for the endless immensity of the sea.
#
# m you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and work, but rather teach them to long for the endless immensity of the sea.
#
# l you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and work, but rather teach them to long for the endless immensity of the sea.
#
# g you want to build a ship, don't drum up people together te collect wood and don't assign them tasks and work, but rather teach them to long for the endless immensity of the sea.
#
# g you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and work, but rather teach them to long for the endless immensity of the sea.
#
# m you want to build a ship, don't drum up people together to collect wood and don't assign them tasks and work, but rather teach them to long for the endless immensity of the sea.
